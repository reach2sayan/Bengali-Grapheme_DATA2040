# %%
import numpy as np
import os

files = [file for file in os.listdir('./raw_images/') if os.path.isfile(os.path.join('./raw_images', file))]

random_files = np.random.choice(files, int(len(files)*.1))
[shutil.copy(os.path.join('./raw_images',file),'./toy_raw_images/') for file in random_files];
